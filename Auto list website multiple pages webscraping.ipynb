# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1686910519,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB5JF148467',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF148467',
#   'clickoff_url': 'https://www.carmax.com/car/24451838?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 267392309,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24451838/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--mWVW41VD--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24451838/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$35,998',
#   'price_unformatted': 35998,
#   'mileage': '46,516 Miles',
#   'mileage_unformatted': 46516,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB5JF148467',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB5JF148467',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '24451838',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689372800,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3MF929094',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3MF929094',
#   'clickoff_url': 'https://www.carmax.com/car/23888491?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269230400,
#   'primary_photo_url': 'https://img2.carmax.com/assets/23888491/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--3uyFBL3W--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/23888491/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$36,998',
#   'price_unformatted': 36998,
#   'mileage': '7,568 Miles',
#   'mileage_unformatted': 7568,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA3MF929094',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA3MF929094',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '23888491',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689286442,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA5KF394931',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA5KF394931',
#   'clickoff_url': 'https://www.carmax.com/car/24452629?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269147732,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24452629/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--GQng4O73--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24452629/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$33,998',
#   'price_unformatted': 33998,
#   'mileage': '43,631 Miles',
#   'mileage_unformatted': 43631,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA5KF394931',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA5KF394931',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '24452629',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1686953753,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB0JF184079',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0JF184079',
#   'clickoff_url': 'https://www.carmax.com/car/24485919?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 267445949,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24485919/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8BaB3Obn--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24485919/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 38.27872113250454,
#   'lon': -122.0043812304184,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$39,998',
#   'price_unformatted': 39998,
#   'mileage': '14,211 Miles',
#   'mileage_unformatted': 14211,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 41,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB0JF184079',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB0JF184079',
#    'remote_dealer_id': '6048',
#    'dealer_name': 'CarMax Fairfield',
#    'remote_sku': '24485919',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689307116,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA4JF039103',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4JF039103',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269177617,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/07/25/00/19/2018_tesla_model_3-pic-979182064618490084-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--BhhlRIcl--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/07/25/00/19/2018_tesla_model_3-pic-979182064618490084-1024x768.jpeg',
#   'lat': 37.41993629015744,
#   'lon': -122.0692477638048,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$35,900',
#   'price_unformatted': 35900,
#   'mileage': '14,550 Miles',
#   'mileage_unformatted': 14550,
#   'city': 'Mountain View',
#   'state': 'CA',
#   'distance_from_origin': 31,
#   'dealer_name': 'Ever Cars Co',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA4JF039103',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '361635230',
#    'remote_dealer_id': '451571',
#    'dealer_name': None,
#    'remote_sku': '000005',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1683368098,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8NF147665',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8NF147665',
#   'clickoff_url': 'https://www.carmax.com/car/24029310?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 264720991,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24029310/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8bXYWoZR--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24029310/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$36,998',
#   'price_unformatted': 36998,
#   'mileage': '18,748 Miles',
#   'mileage_unformatted': 18748,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8NF147665',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA8NF147665',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '24029310',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Base',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689243213,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/7SAYGDEF5NF344342',
#   'vdp_url': '/tesla-model+y#vin=7SAYGDEF5NF344342',
#   'clickoff_url': 'https://www.carmax.com/car/24038877?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269102966,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24038877/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_aKnNFEU--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24038877/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.680492,
#   'lon': -122.45297,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$50,998',
#   'price_unformatted': 50998,
#   'mileage': '21,874 Miles',
#   'mileage_unformatted': 21874,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '7SAYGDEF5NF344342',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '7SAYGDEF5NF344342',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '24038877',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689698211,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E61MF447291',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E61MF447291',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269418883,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/07/26/07/31/2021_tesla_model_s-pic-440583429424656906-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Vt-ztjxn--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/07/26/07/31/2021_tesla_model_s-pic-440583429424656906-1024x768.jpeg',
#   'lat': 37.3231,
#   'lon': -121.988,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$76,888',
#   'price_unformatted': 76888,
#   'mileage': '37,269 Miles',
#   'mileage_unformatted': 37269,
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'distance_from_origin': 39,
#   'dealer_name': 'Stevens Creek Nissan',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E61MF447291',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '361946735',
#    'remote_dealer_id': '368548',
#    'dealer_name': None,
#    'remote_sku': '5063S',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Plaid',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1686564906,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJYGDEE2LF013820',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDEE2LF013820',
#   'clickoff_url': 'https://www.carmax.com/car/24296449?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 267135040,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24296449/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--CCQJBwDv--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24296449/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 38.27872113250454,
#   'lon': -122.0043812304184,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model Y',
#   'model_id': 2357,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '37,557 Miles',
#   'mileage_unformatted': 37557,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 41,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJYGDEE2LF013820',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJYGDEE2LF013820',
#    'remote_dealer_id': '6048',
#    'dealer_name': 'CarMax Fairfield',
#    'remote_sku': '24296449',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1685398547,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA8MF068463',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF068463',
#   'clickoff_url': 'https://www.carmax.com/car/24485173?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 266232458,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24485173/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kGMDY9EM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24485173/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 38.39414581921437,
#   'lon': -122.7426700990229,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$34,998',
#   'price_unformatted': 34998,
#   'mileage': '25,517 Miles',
#   'mileage_unformatted': 25517,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Santa Rosa - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA8MF068463',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA8MF068463',
#    'remote_dealer_id': '6077',
#    'dealer_name': 'CarMax Santa Rosa',
#    'remote_sku': '24485173',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_santa_rosa',
#    'dealer_uuid': '65995b5c-37dd-4c3e-9d1f-1e4cddf4565c',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1688768029,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6MF977687',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6MF977687',
#   'clickoff_url': 'https://www.carmax.com/car/24473836?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 268784651,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24473836/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--LiS9M4fV--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24473836/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.67825483705325,
#   'lon': -121.9129676305049,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$36,998',
#   'price_unformatted': 36998,
#   'mileage': '17,656 Miles',
#   'mileage_unformatted': 17656,
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'distance_from_origin': 28,
#   'dealer_name': 'CarMax Pleasanton - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6MF977687',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA6MF977687',
#    'remote_dealer_id': '6068',
#    'dealer_name': 'CarMax Pleasanton',
#    'remote_sku': '24473836',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_pleasanton',
#    'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1666720991,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE24JF100032',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE24JF100032',
#   'clickoff_url': 'https://www.lithia.com/catcher.esl?vin=5YJXCDE24JF100032&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 253082120,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/05/25/20/52/2018_tesla_model_x-pic-2993005310785737271-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--WLae3_i5--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/05/25/20/52/2018_tesla_model_x-pic-2993005310785737271-1024x768.jpeg',
#   'lat': 38.4105,
#   'lon': -122.719,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$48,524',
#   'price_unformatted': 48524,
#   'mileage': '55,474 Miles',
#   'mileage_unformatted': 55474,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'Lithia Chrysler Jeep Dodge Of Santa Rosa',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJXCDE24JF100032',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '342218990',
#    'remote_dealer_id': '60398',
#    'dealer_name': 'Lithia Chrysler Jeep Dodge of Santa Rosa',
#    'remote_sku': 'P1355',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'lithia_chrysler_jeep_dodgeof_santa_rosa',
#    'dealer_uuid': '854da0e9-8c99-480f-a288-6a3905318ae0',
#    'dealer_group_unique_name': 'lithia_cargurus',
#    'dealer_group_uuid': 'c0fa20c8-42ae-44e3-a134-36b48b15907a'},
#   'trim': '100D',
#   'provider_id': 199,
#   'provider_group_id': 229,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1688120004,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB9NF165195',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB9NF165195',
#   'clickoff_url': 'https://www.carmax.com/car/24341489?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 268328004,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24341489/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--S4k6ZeIp--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24341489/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$43,998',
#   'price_unformatted': 43998,
#   'mileage': '7,534 Miles',
#   'mileage_unformatted': 7534,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 46,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB9NF165195',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB9NF165195',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '24341489',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689113642,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB8JF103278',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8JF103278',
#   'clickoff_url': 'https://www.carmax.com/car/24296706?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 268981223,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24296706/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--UR6K9s3u--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24296706/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 38.27872113250454,
#   'lon': -122.0043812304184,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$36,998',
#   'price_unformatted': 36998,
#   'mileage': '55,896 Miles',
#   'mileage_unformatted': 55896,
#   'city': 'Fairfield',
#   'state': 'CA',
#   'distance_from_origin': 41,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB8JF103278',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB8JF103278',
#    'remote_dealer_id': '6048',
#    'dealer_name': 'CarMax Fairfield',
#    'remote_sku': '24296706',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Performance',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1687139239,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7JF012588',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF012588',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 267598234,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/06/23/15/55/2018_tesla_model_3-pic-6270206750971308804-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tVQI44Nn--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/06/23/15/55/2018_tesla_model_3-pic-6270206750971308804-1024x768.jpeg',
#   'lat': 37.9645,
#   'lon': -122.513,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$33,600',
#   'price_unformatted': 33600,
#   'mileage': '41,864 Miles',
#   'mileage_unformatted': 41864,
#   'city': 'San Rafael',
#   'state': 'CA',
#   'distance_from_origin': 14,
#   'dealer_name': 'Volvo Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA7JF012588',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '359752899',
#    'remote_dealer_id': '94913',
#    'dealer_name': None,
#    'remote_sku': '23464A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1688206393,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB0JF128871',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB0JF128871',
#   'clickoff_url': 'https://www.carmax.com/car/24039002?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 268406249,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24039002/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--V7rT2F4M--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24039002/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.69056829597337,
#   'lon': -122.4466776578749,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$33,998',
#   'price_unformatted': 33998,
#   'mileage': '57,413 Miles',
#   'mileage_unformatted': 57413,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB0JF128871',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB0JF128871',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '24039002',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1689372826,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E29MF425634',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E29MF425634',
#   'clickoff_url': 'https://www.carmax.com/car/24120300?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 269230722,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24120300/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--59w7LyBj--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24120300/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.67825483705325,
#   'lon': -121.9129676305049,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$57,998',
#   'price_unformatted': 57998,
#   'mileage': '50,813 Miles',
#   'mileage_unformatted': 50813,
#   'city': 'Pleasanton',
#   'state': 'CA',
#   'distance_from_origin': 28,
#   'dealer_name': 'CarMax Pleasanton - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJSA1E29MF425634',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJSA1E29MF425634',
#    'remote_dealer_id': '6068',
#    'dealer_name': 'CarMax Pleasanton',
#    'remote_sku': '24120300',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_pleasanton',
#    'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1684577729,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3KF306412',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3KF306412',
#   'clickoff_url': 'https://www.carmax.com/car/24209689?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 265640545,
#   'primary_photo_url': 'https://img2.carmax.com/assets/24209689/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--RBvHJU2I--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24209689/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#   'lat': 37.50613267061532,
#   'lon': -121.965889235115,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$30,998',
#   'price_unformatted': 30998,
#   'mileage': '46,573 Miles',
#   'mileage_unformatted': 46573,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 30,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA3KF306412',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA3KF306412',
#    'remote_dealer_id': '6071',
#    'dealer_name': 'CarMax Fremont',
#    'remote_sku': '24209689',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1660313459,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCDE47HF055812',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE47HF055812',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 248618294,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/05/09/07/46/2017_tesla_model_x-pic-737641527286956138-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2-4jCCjG--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/05/09/07/46/2017_tesla_model_x-pic-737641527286956138-1024x768.jpeg',
#   'lat': 37.32309,
#   'lon': -121.987602,
#   'year': 2017,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$59,888',
#   'price_unformatted': 59888,
#   'mileage': '20,223 Miles',
#   'mileage_unformatted': 20223,
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'distance_from_origin': 39,
#   'dealer_name': 'Stevens Creek Nissan',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJXCDE47HF055812',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '336807106',
#    'remote_dealer_id': '368548',
#    'dealer_name': None,
#    'remote_sku': '4620PAR',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'P100D',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1683773164,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1H11EFP53795',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1H11EFP53795',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 265005248,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2023/05/26/15/55/2014_tesla_model_s-pic-4301312144206204753-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qD8JArpX--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2023/05/26/15/55/2014_tesla_model_s-pic-4301312144206204753-1024x768.jpeg',
#   'lat': 37.6546,
#   'lon': -122.07,
#   'year': 2014,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$27,497',
#   'price_unformatted': 27497,
#   'mileage': '80,522 Miles',
#   'mileage_unformatted': 80522,
#   'city': 'Hayward',
#   'state': 'CA',
#   'distance_from_origin': 20,
#   'dealer_name': 'Hayward Mitsubishi',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1H11EFP53795',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '356658886',
#    'remote_dealer_id': '379284',
#    'dealer_name': None,
#    'remote_sku': '24103',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': '85',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1686910519,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EB5JF148467',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5JF148467',
#  'clickoff_url': 'https://www.carmax.com/car/24451838?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 267392309,
#  'primary_photo_url': 'https://img2.carmax.com/assets/24451838/image/1.jpg?width=1024&height=768&wm=LYCG_1a.png',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--mWVW41VD--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/assets/24451838/image/1.jpg%3Fwidth%3D1024%26height%3D768%26wm%3DLYCG_1a.png',
#  'lat': 37.69056829597337,
#  'lon': -122.4466776578749,
#  'year': 2018,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$35,998',
#  'price_unformatted': 35998,
#  'mileage': '46,516 Miles',
#  'mileage_unformatted': 46516,
#  'city': 'Colma',
#  'state': 'CA',
#  'distance_from_origin': 6,
#  'dealer_name': 'CarMax Serramonte - Now Open',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '5YJ3E1EB5JF148467',
#  'provider': None,
#  'provider_name': 'carmax',
#  'always_ask_for_zip': True,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '5YJ3E1EB5JF148467',
#   'remote_dealer_id': '6080',
#   'dealer_name': 'CarMax Serramonte',
#   'remote_sku': '24451838',
#   'experience': 'local',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'carmax_serramonte',
#   'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#   'dealer_group_unique_name': 'carmax',
#   'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#  'trim': 'Performance',
#  'provider_id': 146,
#  'provider_group_id': 149,
#  'experience': 'local_if_nearby',
#  'regional': False,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': False}

# %%
# model 
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '46,516 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2018

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Serramonte - Now Open'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$35,998'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year']) 
    
    # dealer name
    dealer_name.append(result['dealer_name']) 
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year  \
# 0   Model 3  46,516 Miles  2018
# 1   Model 3   7,568 Miles  2021
# 2   Model 3  43,631 Miles  2019
# 3   Model 3  14,211 Miles  2018
# 4   Model 3  14,550 Miles  2018
# 5   Model 3  18,748 Miles  2022
# 6   Model Y  21,874 Miles  2022
# 7   Model S  37,269 Miles  2021
# 8   Model Y  37,557 Miles  2020
# 9   Model 3  25,517 Miles  2021
# 10  Model 3  17,656 Miles  2021
# 11  Model X  55,474 Miles  2018
# 12  Model 3   7,534 Miles  2022
# 13  Model 3  55,896 Miles  2018
# 14  Model 3  41,864 Miles  2018
# 15  Model 3  57,413 Miles  2018
# 16  Model S  50,813 Miles  2021
# 17  Model 3  46,573 Miles  2019
# 18  Model X  20,223 Miles  2017
# 19  Model S  80,522 Miles  2014
#
#                                           Dealer Name    Price
# 0                        CarMax Serramonte - Now Open  $35,998
# 1                        CarMax Serramonte - Now Open  $36,998
# 2                CarMax Capitol Expressway - Now Open  $33,998
# 3   CarMax Fairfield - Now Offering Curbside Picku...  $39,998
# 4                                        Ever Cars Co  $35,900
# 5                CarMax Capitol Expressway - Now Open  $36,998
# 6                        CarMax Serramonte - Now Open  $50,998
# 7                                Stevens Creek Nissan  $76,888
# 8   CarMax Fairfield - Now Offering Curbside Picku...  $44,998
# 9                        CarMax Santa Rosa - Now Open  $34,998
# 10                       CarMax Pleasanton - Now Open  $36,998
# 11           Lithia Chrysler Jeep Dodge Of Santa Rosa  $48,524
# 12               CarMax Capitol Expressway - Now Open  $43,998
# 13  CarMax Fairfield - Now Offering Curbside Picku...  $36,998
# 14                                        Volvo Marin  $33,600
# 15                       CarMax Serramonte - Now Open  $33,998
# 16                       CarMax Pleasanton - Now Open  $57,998
# 17                          CarMax Fremont - Now Open  $30,998
# 18                               Stevens Creek Nissan  $59,888
# 19                                 Hayward Mitsubishi  $27,497

# %%
tesla_df.to_excel('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year']) 

        # dealer name
        dealer_name.append(result['dealer_name']) 

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year  \
# 0   Model 3  46,516 Miles  2018
# 1   Model 3   7,568 Miles  2021
# 2   Model 3  43,631 Miles  2019
# 3   Model 3  14,211 Miles  2018
# 4   Model 3  14,550 Miles  2018
# ..      ...           ...   ...
# 95  Model 3  10,726 Miles  2023
# 96  Model Y  51,902 Miles  2020
# 97  Model Y  24,911 Miles  2021
# 98  Model 3  36,411 Miles  2019
# 99  Model 3  33,516 Miles  2019
#
#                                           Dealer Name    Price
# 0                        CarMax Serramonte - Now Open  $35,998
# 1                        CarMax Serramonte - Now Open  $36,998
# 2                CarMax Capitol Expressway - Now Open  $33,998
# 3   CarMax Fairfield - Now Offering Curbside Picku...  $39,998
# 4                                        Ever Cars Co  $35,900
# ..                                                ...      ...
# 95                          CarMax Fremont - Now Open  $39,998
# 96                       CarMax Santa Rosa - Now Open  $43,998
# 97                       CarMax Santa Rosa - Now Open  $49,998
# 98                          CarMax Fremont - Now Open  $33,998
# 99               CarMax Capitol Expressway - Now Open  $31,998
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx', index=False)
